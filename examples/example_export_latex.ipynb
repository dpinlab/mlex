# %% [markdown]
# # LaTeX Export Example for PCPEDataExploratoryAnalysis
#
# This notebook demonstrates how to use the `export_all_analyses_latex` method to generate LaTeX tables for all analyses.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

# Add the project root to Python path for Jupyter notebooks
project_root = Path.cwd().parent.parent
sys.path.append(str(project_root))

# %%
# Import required libraries
import pandas as pd
import numpy as np
from mlex import PCPEDataExploratoryAnalysis, DataReader
import os

# Set up display options for better output
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
data_path = r'/data/pcpe/pcpe_04.csv'
target_column = 'I-d'

reader = DataReader(data_path, target_columns=[target_column])
df = reader.read_df()
print(f"Sample dataset created with {len(df)} transactions")
print(f"Columns: {list(df.columns)}")
df.head()
# Out:
# Sample dataset created with 59239 transactions
# Columns: ['NUMERO_CASO', 'NUMERO_BANCO', 'NOME_BANCO', 'NUMERO_AGENCIA', 'NUMERO_CONTA', 'TIPO', 'CPF_CNPJ_TITULAR', 'NOME_TITULAR', 'DATA_LANCAMENTO', 'CPF_CNPJ_OD', 'NOME_PESSOA_OD', 'CNAB', 'DESCRICAO_LANCAMENTO', 'VALOR_TRANSACAO', 'NATUREZA_LANCAMENTO', 'I-d', 'I-e', 'IV-n', 'RAMO_ATIVIDADE_1', 'RAMO_ATIVIDADE_2', 'RAMO_ATIVIDADE_3', 'LOCAL_TRANSACAO', 'NUMERO_DOCUMENTO', 'NUMERO_DOCUMENTO_TRANSACAO', 'VALOR_SALDO', 'NATUREZA_SALDO', 'NUMERO_BANCO_OD', 'NUMERO_AGENCIA_OD', 'NUMERO_CONTA_OD', 'NOME_ENDOSSANTE_CHEQUE', 'DOC_ENDOSSANTE_CHEQUE', 'DIA_LANCAMENTO', 'MES_LANCAMENTO', 'ANO_LANCAMENTO', 'CONTA_TITULAR', 'CONTA_OD']
#              NUMERO_CASO NUMERO_BANCO                  NOME_BANCO  \
# 0  EXTRATO-NOVO-2-A4I4Q8          889                 SANTOS S.A.
# 1  EXTRATO-NOVO-2-A4I4Q8           12  ALBUQUERQUE NASCIMENTO S/A
# 2  EXTRATO-NOVO-2-A4I4Q8           12  ALBUQUERQUE NASCIMENTO S/A
# 3  EXTRATO-NOVO-2-A4I4Q8           12  ALBUQUERQUE NASCIMENTO S/A
# 4  EXTRATO-NOVO-2-A4I4Q8           12  ALBUQUERQUE NASCIMENTO S/A
#
#   NUMERO_AGENCIA NUMERO_CONTA TIPO CPF_CNPJ_TITULAR  NOME_TITULAR  \
# 0            404    6768049-v    2      61853074993     CAIO DIAS
# 1           9541    1789979-J    1      10534298605  SOFIA GUERRA
# 2           9541    6265306-w    1      10534298605  SOFIA GUERRA
# 3           9541    6265306-w    1      10534298605  SOFIA GUERRA
# 4           9541    6265306-w    1      10534298605  SOFIA GUERRA
#
#   DATA_LANCAMENTO  CPF_CNPJ_OD      NOME_PESSOA_OD CNAB  \
# 0      2019-01-01  35720986103       ANDRÉ DA CRUZ  218
# 1      2019-01-02  54390287656  MARIA CLARA DUARTE  117
# 2      2019-01-02  78031569240      EDUARDA DA LUZ  101
# 3      2019-01-02  92401638750        RAUL CORREIA  110
# 4      2019-01-02  92401638750       ÍSIS CASSIANO  102
#
#     DESCRICAO_LANCAMENTO  VALOR_TRANSACAO NATUREZA_LANCAMENTO  I-d  I-e  IV-n  \
# 0             CRED JUROS             0.01                   C    0    0     0
# 1  TRANSFERENCIA ON LINE           190.00                   D    0    0     0
# 2      CHEQUE COMPENSADO           300.00                   D    0    0     0
# 3     COBRANCA DE I.O.F.             8.03                   D    0    0     0
# 4      COBRANCA DE JUROS            10.84                   D    0    0     0
#
#   RAMO_ATIVIDADE_1 RAMO_ATIVIDADE_2 RAMO_ATIVIDADE_3 LOCAL_TRANSACAO  \
# 0                1                0                0             NaN
# 1                1                0                0        INTERNET
# 2                1                0                0             NaN
# 3                1                0                0             NaN
# 4                1                0                0             NaN
#
#   NUMERO_DOCUMENTO NUMERO_DOCUMENTO_TRANSACAO  VALOR_SALDO NATUREZA_SALDO  \
# 0                0                          0       486.00              C
# 1  602480000010308            602480000010308        71.88              D
# 2           447630                     447630       365.17              D
# 3        391100701                  391100701       436.51              D
# 4        511058924                  511058924       428.48              D
#
#   NUMERO_BANCO_OD NUMERO_AGENCIA_OD NUMERO_CONTA_OD NOME_ENDOSSANTE_CHEQUE  \
# 0               0                 0             NaN                    NaN
# 1              12              9541       1938878-U                    NaN
# 2             313              2196       5760743-O                    NaN
# 3              12              9541       0883468-y                    NaN
# 4              12              9541       5979787-N                    NaN
#
#   DOC_ENDOSSANTE_CHEQUE  DIA_LANCAMENTO  MES_LANCAMENTO  ANO_LANCAMENTO  \
# 0                   NaN               1               1            2019
# 1                   NaN               2               1            2019
# 2                   NaN               2               1            2019
# 3                   NaN               2               1            2019
# 4                   NaN               2               1            2019
#
#        CONTA_TITULAR            CONTA_OD
# 0  889_404_6768049-v               EMPTY
# 1  12_9541_1789979-J   12_9541_1938878-U
# 2  12_9541_6265306-w  313_2196_5760743-O
# 3  12_9541_6265306-w   12_9541_0883468-y
# 4  12_9541_6265306-w   12_9541_5979787-N

# %%
# Initialize the PCPEDataExploratoryAnalysis class
analyzer = PCPEDataExploratoryAnalysis(df)

# %%
# Export all analyses to LaTeX tables
# This will create individual .tex files for each analysis

latex_tables = analyzer.export_all_analyses_latex(
    output_dir="latex_tables",           # Directory to save .tex files
    top_n=10,                           # Number of top items in ranking tables
    typology_columns=['I-d']  # Specific typologies to analyze
)

print(f"\nGenerated {len(latex_tables)} LaTeX tables:")
for name in latex_tables.keys():
    print(f"  - {name}.tex")
# Out:
# Saved LaTeX table: latex_tables/data_quality.tex
# Saved LaTeX table: latex_tables/missing_data.tex
# Saved LaTeX table: latex_tables/bank_analysis.tex
# Saved LaTeX table: latex_tables/agency_analysis.tex
# Saved LaTeX table: latex_tables/individual_analysis.tex
# Saved LaTeX table: latex_tables/account_analysis.tex
# Saved LaTeX table: latex_tables/cross_bank_agency.tex
# Saved LaTeX table: latex_tables/cross_bank_individual.tex
# Saved LaTeX table: latex_tables/cross_agency_individual.tex
# Saved LaTeX table: latex_tables/typology_I-d.tex
#
# Generated 10 LaTeX tables:
#   - data_quality.tex
#   - missing_data.tex
#   - bank_analysis.tex
#   - agency_analysis.tex
#   - individual_analysis.tex
#   - account_analysis.tex
#   - cross_bank_agency.tex
#   - cross_bank_individual.tex
#   - cross_agency_individual.tex
#   - typology_I-d.tex

# %%
# Display the content of one of the generated LaTeX tables
print("Example LaTeX table content (Bank Analysis):")
print("=" * 60)
print(latex_tables['bank_analysis'])

# %%
# Check the generated files
if os.path.exists("latex_tables"):
    files = os.listdir("latex_tables")
    print(f"Generated files in 'latex_tables' directory:")
    for file in sorted(files):
        if file.endswith('.tex'):
            file_path = os.path.join("latex_tables", file)
            file_size = os.path.getsize(file_path)
            print(f"  - {file} ({file_size} bytes)")
else:
    print("No latex_tables directory found")

# %%
# Generate a complete LaTeX document with all analyses
latex_document = analyzer.generate_latex_document(
    output_file="complete_analysis_report.tex",
    title="Financial Transaction Analysis Report",
    author="Data Analysis Team",
    top_n=10,
    typology_columns=['I-d', 'Risk_Level', 'Suspicious_Flag']
)

print(f"Complete LaTeX document generated: {latex_document}")

# Check if the document was created
if os.path.exists("complete_analysis_report.tex"):
    file_size = os.path.getsize("complete_analysis_report.tex")
    print(f"Document size: {file_size} bytes")
    
    # Show first few lines of the document
    with open("complete_analysis_report.tex", 'r', encoding='utf-8') as f:
        lines = f.readlines()[:20]  # First 20 lines
        print("\nFirst 20 lines of the LaTeX document:")
        print("-" * 50)
        for i, line in enumerate(lines, 1):
            print(f"{i:2d}: {line.rstrip()}")

# %%
# Example: Export specific analyses with custom settings
print("Exporting specific analyses with custom settings:")
print("=" * 60)

# Export bank analysis with custom caption and top 15 banks
bank_latex = analyzer.export_bank_analysis_latex(
    top_n=15,
    caption="Top 15 Banks by Transaction Volume and Distribution",
    label="tab:top_banks_detailed"
)
print("Bank Analysis LaTeX:")
print(bank_latex)
print("\n" + "="*60 + "\n")

# Export typology analysis with custom settings
typology_latex = analyzer.export_typology_analysis_latex(
    typology_column='Risk_Level',
    typology_name='Risk Assessment',
    caption="Risk Level Distribution Analysis",
    label="tab:risk_analysis"
)
print("Risk Level Typology Analysis LaTeX:")
print(typology_latex)

# %%
# Save individual LaTeX tables to files with custom names
custom_tables = {
    'bank_analysis_custom.tex': analyzer.export_bank_analysis_latex(top_n=20),
    'risk_analysis_custom.tex': analyzer.export_typology_analysis_latex('Risk_Level'),
    'missing_data_custom.tex': analyzer.export_missing_data_analysis_latex()
}

# Create custom directory
custom_dir = "custom_latex_tables"
os.makedirs(custom_dir, exist_ok=True)

# Save custom tables
for filename, latex_content in custom_tables.items():
    filepath = os.path.join(custom_dir, filename)
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(latex_content)
    print(f"Saved: {filepath}")

print(f"\nCustom LaTeX tables saved in '{custom_dir}' directory")

# %% [markdown]
# ## Summary
#
# This example demonstrates:
#
# 1. **Basic Usage**: Using `export_all_analyses_latex()` to generate all analysis tables
# 2. **Custom Settings**: Specifying output directory, top N items, and typology columns
# 3. **Individual Exports**: Exporting specific analyses with custom captions and labels
# 4. **Complete Document**: Generating a full LaTeX document with all analyses
# 5. **File Management**: Organizing and saving LaTeX files in custom directories
#
# The generated LaTeX files can be:
# - Included in your LaTeX documents using `\input{filename.tex}`
# - Compiled directly with `pdflatex`
# - Used in academic papers, reports, or presentations

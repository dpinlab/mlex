# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("../..")
sys.path.append("../../..")

import pandas as pd
import numpy as np
from mlex import DataReader
# Out:
# 2025-05-21 23:39:31.416267: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747881571.435099   10546 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747881571.440760   10546 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747881571.455428   10546 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747881571.455450   10546 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747881571.455451   10546 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747881571.455453   10546 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-21 23:39:31.460313: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import torch

target_column = 'I-d'
filter_data = {'NATUREZA_LANCAMENTO': 'C'}
path = r'/data/pcpe/pcpe_03.csv'

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

reader = DataReader(path, target_columns=[target_column], filter_dict=filter_data)
reader.fit(insert_noise=True)
X = reader.fit_transform(X=None)
y = reader.get_target()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       7 device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
#       9 reader = DataReader(path, target_columns=[target_column], filter_dict=filter_data)
# ---> 10 reader.fit(insert_noise=True)
#      11 X = reader.fit_transform(X=None)
#      12 y = reader.get_target()
#
# File /data/isa/mlex/publications/cbic2025/../../mlex/utils/datareader.py:104, in DataReader.fit(self, insert_noise, X, y)
#     101 if insert_noise == True:
#     102     df = self.inserting_noise(df)
# --> 104 self.y = df[self.target_columns]
#     105 self.X = df.drop(columns=self.target_columns, axis=1)
#     106 return self
#
# TypeError: 'NoneType' object is not subscriptable
